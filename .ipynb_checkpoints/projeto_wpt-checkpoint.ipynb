# %%
from math import *
from cmath import *
from numpy import linalg
import numpy as np
import matplotlib.pyplot as plt

# %%
R1 = R2 = 0.5
Rdc = 0.5
L1 = L2 = 300e-6
C1 = C2 = 0.1e-6
Rc = 10
f = 60
k = 0.1

# %%
def CalcularTransformador(v1, Rc, f) -> tuple[complex, complex]:
    w = 2*pi*f
    M = sqrt(L1*L2)*k
    XL1 = L1*w*1j
    XL2 = L2*w*1j
    XM = M*w*1j

    XC1 = 1/(C1*w*1j)
    XC2 = 1/(C2*w*1j)

    Z=np.array([[(R1+XL1+XC1), -XM],[-XM, XL2+R2+((Rc * XC2)/(XC2 + Rc))]])
    V=np.array([v1,0])
    I=np.dot(linalg.inv(Z),V)
    return I[0], I[1]

i1, i2 = CalcularTransformador(50, Rc, f)
print(f"i1 transformador: {abs(i1)}, {phase(i1)}")
print(f"i2 transformador: {abs(i2)}, {phase(i2)}")
# Out:
# i1 transformador: 0.001884963628671156, 1.5707774766994094
# i2 transformador: 2.0302175031442833e-06, 3.1311620426265265

# %%
ListaC = [150*1e-9, 0.1*1e-6, 0.47*1e-6, 1e-6, 4.7*1e-6]
lista_fr = np.linspace(1, 100e3, 1000)
for cap in ListaC:
    C1 = C2 = cap
    lista_V2 = []
    for freq in lista_fr:
        w=2*pi*freq
        L1 = L2 =1/(w*w*cap)
        XC1 = XC2 = 1/(cap*1j*w)
        R1 = Rdc + (2*Rdc/100e3) *freq
        R2 = R1
        i1, i2 = CalcularTransformador(10, Rc, freq)
        i4 = ((XC2*i2)/(XC2+Rc))
        lista_V2.append(abs(Rc*i4))

    plt.plot(lista_fr, lista_V2, label=f"C = {cap * 1e9:.2f} nF")

plt.xlabel('Frequência (Hz)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.show()

# %%
max_f = []
for cap in ListaC:
    C1 = C2 = cap
    lista_V2 = []
    for freq in lista_fr:
        w = 2 * pi * freq
        L1 = L2 = 1 / (w * w * cap)
        XC1 = XC2 = 1 / (cap * 1j * w)
        R1 = Rdc + (2 * Rdc / 100e3) * freq
        R2 = R1
        i1, i2 = CalcularTransformador(10, Rc, freq)
        i4 = ((XC2 * i2) / (XC2 + Rc))
        lista_V2.append(abs(Rc * i4))

    # Encontrar o índice do valor máximo de lista_V2
    indice_maximo = np.argmax(lista_V2)
    # Obter a frequência correspondente ao valor máximo
    freq_maxima = lista_fr[indice_maximo]
    max_f.append(freq_maxima)

    plt.plot(lista_fr, lista_V2, label=f"C = {cap * 1e9:.2f} nF")
    plt.scatter(freq_maxima, lista_V2[indice_maximo], color='red')  # Marcando o ponto máximo

    # Adicionando texto com o valor máximo
    plt.text(freq_maxima, lista_V2[indice_maximo], f"Freq máxima: {freq_maxima:.2f} Hz", fontsize=8)

plt.xlabel('Frequência (Hz)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.show()

# %%
indutancias = []
for i in range(len(ListaC)):
    indutancia = (1/(2*pi*max_f[i])**2)*(1/ListaC[i])
    indutancias.append(indutancia*1e3)
print(indutancias)
min_ind = min(indutancias)
min_c = ListaC[indutancias.index(min_ind)]
print(min_ind)
print(min_c)

ind = (1/(2*pi*8510)**2)*(1/1e-6)
print(ind*1e3)
# Out:
# [0.3077654543699659, 0.28087202953382107, 0.4211612383467213, 0.5465557937821668, 1.2185135759805104]
# 0.28087202953382107
# 1e-07
# 0.34976886127724816

# %%
f = 8500
w = 2*pi*f
c  = 1e-6
l = 1/(w*w*c)

print(l)
# Out:
# 0.0003505923309423453

# %%
R1 = 677.3e-3
R2 = 696.6e-3
Rdc = 0.5
L1 = 361.6e-6
L2 = 367.6e-6
C1 = C2 = 1e-6
Rc = 10
f = 8500
k = 0.1

# %%
def CalcularTransformador(vp, Rc, f, k) -> tuple[complex, complex]:
    w = 2*pi*f
    M = sqrt(L1*L2)*k
    XL1 = L1*w*1j
    XL2 = L2*w*1j
    XM = M*w*1j
    vi = (2/pi)*vp

    XC1 = 1/(C1*w*1j)
    XC2 = 1/(C2*w*1j)

    Z=np.array([[(R1+XL1+XC1), -XM],[-XM, XL2+R2+((Rc * XC2)/(XC2 + Rc))]])
    V=np.array([vp,0])
    I=np.dot(linalg.inv(Z),V)
    return I[0], I[1]

# %%
lista_k = np.linspace(0, 1, 100)
lista_V2 = []
lista_correntei4 = []
v2_max = 0
k_m = 0
for k in lista_k:
    w=2*pi*f
    L1 = L2 =1/(w*w*C1)
    XC1 = XC2 = 1/(C1*1j*w)
    R1 = Rdc1 + (2*Rdc1/100e3) *f
    R2 = Rdc2 + (2*Rdc2/100e3) *f
    i1, i2 = CalcularTransformador(15, Rc, f, k)
    i4 = ((XC2*i2)/(XC2+Rc))
    lista_correntei4.append(abs(i4))
    lista_V2.append(abs(Rc*i4))
    if abs(Rc*i4) > v2_max:
        v2_max = abs(Rc*i4)
        k_m = k
    
k_max = lista_k[lista_V2.index(max(lista_V2))]
print(k_max)
print(k_m)
print(max(lista_V2))
print(max(lista_correntei4))
plt.plot(lista_k, lista_V2)
plt.xlabel("Valores de acoplamento (k)")
plt.ylabel("Tensão V2 eficaz")
plt.title("Tensão X Acoplamento")
plt.grid()
plt.show()

plt.plot(lista_correntei4, lista_V2)
plt.xlabel("Corrente")
plt.ylabel("Tensão")
plt.title("Tensao por corrente")
plt.grid()
plt.show()
# Out:
# 0.19191919191919193
# 0.19191919191919193
# 20.803509056215578
# 2.080350905621558
